# %% [markdown]
# ## 🎓 Master's Project: Comparative Streaming Content Analysis (Netflix vs. Prime Video)
# Subject: Big Data and AI
#
# Objective: To integrate disparate content catalogs from Netflix and Amazon Prime Video, standardize the features, and perform a comparative analysis to develop a prescriptive subscription recommendation engine.

# %% [markdown]
# ## 1. Project Setup and Data Loading 📦
# This section sets up the Python environment and loads the raw data from the two distinct streaming platforms.

# %% [markdown]
# ## 1.1 Import Core Libraries
# We import Pandas for data manipulation, Numpy for numerical operations, and Matplotlib/Seaborn for visualizations.

# %% [markdown]
# ## 1.2 Load Raw Data and Add Platform Identifier
# The two raw CSV files are loaded. A crucial first step is adding the platform column to each DataFrame to differentiate content after merging.

# %%
# Assuming your files are in the same directory as your notebook or a 'data/' folder
netflix_df = pd.read_csv('../data/netflix_titles.csv')
prime_df = pd.read_csv('../data/amazon_prime_titles.csv')


# Add the essential 'platform' identifier column to each DataFrame
netflix_df['platform'] = 'Netflix'
prime_df['platform'] = 'Amazon Prime Video'

print("Netflix columns:", netflix_df.columns.tolist())
print("Prime Video columns:", prime_df.columns.tolist())
